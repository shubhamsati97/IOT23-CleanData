# %%
# Reference:
# https://github.com/yliang725/Anomaly-Detection-IoT23/blob/main/Data%20Preprocessing/IoT23%20-%20Data%20Preprocessing.ipynb


import pathlib

import dask.dataframe as pd
iot_23 = pathlib.Path("/home/mohit/data/opt")
files = list(iot_23.rglob("*.labeled"))
files = [str(file) for file in files]

# %%
def minimize_dfs(file:str):
    print(f"Processing file : {file}")
    df = pd.read_table(file, skiprows=8,low_memory=False,dtype='object')
    df.columns = ['ts',
                  'uid',
                  'id.orig_h',
                  'id.orig_p',
                  'id.resp_h',
                  'id.resp_p',
                  'proto',
                  'service',
                  'duration',
                  'orig_bytes',
                  'resp_bytes',
                  'conn_state',
                  'local_orig',
                  'local_resp',
                  'missed_bytes',
                  'history',
                  'orig_pkts',
                  'orig_ip_bytes',
                  'resp_pkts',
                  'resp_ip_bytes',
                  'label']
    # Drop columns
    df = df.drop(columns=['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p',
                                    'service', 'local_orig', 'local_resp', 'history'])
    print(df.head())
#     df=df.drop(df.index[-1])

    # Clean df labels
#     df.loc[(df.label == '-   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
#     df.loc[(df.label == '(empty)   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
#     df.loc[(df.label == '-   Malicious   Okiru'), 'label'] = 'Okiru'
#     df.loc[(df.label == '(empty)   Malicious   Okiru'), 'label'] = 'Okiru'
#     df.loc[(df.label == '-   Benign   -'), 'label'] = 'Benign'
#     df.loc[(df.label == '(empty)   Benign   -'), 'label'] = 'Benign'
#     df.loc[(df.label == '-   Malicious   DDoS'), 'label'] = 'DDoS'
#     df.loc[(df.label == '-   Malicious   C&C'), 'label'] = 'C&C'
#     df.loc[(df.label == '(empty)   Malicious   C&C'), 'label'] = 'C&C'
#     df.loc[(df.label == '-   Malicious   Attack'), 'label'] = 'Attack'
#     df.loc[(df.label == '(empty)   Malicious   Attack'), 'label'] = 'Attack'
#     df.loc[(df.label == '-   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
#     df.loc[(df.label == '(empty)   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
#     df.loc[(df.label == '-   Malicious   C&C-FileDownload'), 'label'] = 'C&C-FileDownload'
#     df.loc[(df.label == '-   Malicious   C&C-Torii'), 'label'] = 'C&C-Torii'
#     df.loc[(df.label == '-   Malicious   C&C-HeartBeat-FileDownload'), 'label'] = 'C&C-HeartBeat-FileDownload'
#     df.loc[(df.label == '-   Malicious   FileDownload'), 'label'] = 'FileDownload'
#     df.loc[(df.label == '-   Malicious   C&C-Mirai'), 'label'] = 'C&C-Mirai'
#     df.loc[(df.label == '-   Malicious   Okiru-Attack'), 'label'] = 'Okiru-Attack'

    # Replace '-' with 0
#     df['duration'] = df['duration'].str.replace('-', '0')
#     df['orig_bytes'] = df['orig_bytes'].str.replace('-', '0')
#     df['resp_bytes'] = df['resp_bytes'].str.replace('-', '0')

#     print(f"Length of the file : {len(df.index)}")
    print(f"Processed file : {file}")
    return df

# %%
import time
for file in files:
    start_time = time.time()
    file_name = file.split('/')[8]
    result = minimize_dfs(file=file)
    result.to_csv(f"data/{file_name}.csv",single_file=True)
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-33-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.006726         48         48         SF            0         1
# 1   udp  0.003734         48         48         SF            0         1
# 2   udp  0.004739         48         48         SF            0         1
# 3   udp  0.004739         48         48         SF            0         1
# 4   udp  0.006741         48         48         SF            0         1
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0            76         1            76  -   Benign   -
# 1            76         1            76  -   Benign   -
# 2            76         1            76  -   Benign   -
# 3            76         1            76  -   Benign   -
# 4            76         1            76  -   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-33-1/bro/conn.log.labeled
# --- 429.3289039134979 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.001494         90         90         SF            0         2
# 1   udp  5.005135         78          0         S0            0         2
# 2   udp  0.001483         90         90         SF            0         2
# 3   udp  5.038625        117        142         SF            0         3
# 4   udp  0.110686         90         90         SF            0         2
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0           146         2           146  -   Benign   -
# 1           134         0             0  -   Benign   -
# 2           146         2           146  -   Benign   -
# 3           201         2           198  -   Benign   -
# 4           146         2           146  -   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled
# --- 0.3988454341888428 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-36-1/bro/conn.log.labeled
#   proto duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp        -          -          -         S0            0         1
# 1   tcp        -          -          -         S0            0         1
# 2   tcp        -          -          -         S0            0         1
# 3   tcp        -          -          -         S0            0         1
# 4   tcp        -          -          -         S0            0         1
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                  label
# 0            40         0             0  -   Malicious   Okiru
# 1            40         0             0  -   Malicious   Okiru
# 2            40         0             0  -   Malicious   Okiru
# 3            40         0             0  -   Malicious   Okiru
# 4            40         0             0  -   Malicious   Okiru
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-36-1/bro/conn.log.labeled
# --- 104.87652134895325 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-48-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp  2.182247        149     119442         SF            0       172
# 1   tcp  1.675550        152      83118         SF            0       124
# 2   tcp  1.798966        149      88797         SF            0       136
# 3   tcp  1.938142        149     117700         SF            0       170
# 4   tcp  3.141713          0          0         S0            0         6
#
#   orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0         11570       170        247740
# 1          8120       122        172596
# 2          8578       134        193266
# 3         11602       170        244256
# 4           360         0             0
#
#                                         label
# 0  -   Malicious   C&C-HeartBeat-FileDownload
# 1  -   Malicious   C&C-HeartBeat-FileDownload
# 2  -   Malicious   C&C-HeartBeat-FileDownload
# 3  -   Malicious   C&C-HeartBeat-FileDownload
# 4   -   Malicious   PartOfAHorizontalPortScan
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-48-1/bro/conn.log.labeled
# --- 30.02897596359253 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled
#   proto    duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp  108.421563       2376         96        OTH            0         5
# 1   tcp    0.001244         21          0         S0            0         3
# 2   tcp    0.000738         21          0         S0            0         3
# 3   udp           -          -          -         S0            0         1
# 4   udp           -          -          -         S0            0         1
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                 label
# 0           332         2           200  (empty)   Benign   -
# 1           189         0             0  (empty)   Benign   -
# 2           189         0             0  (empty)   Benign   -
# 3            58         0             0  (empty)   Benign   -
# 4            58         0             0  (empty)   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled
# --- 56.3727490901947 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp         -          -          -         S0            0         1
# 1   tcp  2.997182          0          0         S0            0         3
# 2   tcp         -          -          -         S0            0         1
# 3   tcp  2.996286          0          0         S0            0         3
# 4   tcp         -          -          -         S0            0         1
#
#   orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0            60         0             0
# 1           180         0             0
# 2            60         0             0
# 3           180         0             0
# 4            60         0             0
#
#                                              label
# 0  (empty)   Malicious   PartOfAHorizontalPortScan
# 1  (empty)   Malicious   PartOfAHorizontalPortScan
# 2  (empty)   Malicious   PartOfAHorizontalPortScan
# 3  (empty)   Malicious   PartOfAHorizontalPortScan
# 4  (empty)   Malicious   PartOfAHorizontalPortScan
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled
# --- 2.117246150970459 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-52-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp  1.954395         86      51041         SF            0        80
# 1   tcp  3.138466          0          0         S0            0         6
# 2   tcp  1.039155        154      73550         SF         1448       108
# 3   tcp  1.055416         87      73550         SF         1448       108
# 4   tcp  3.085242          0          0         S0            0         6
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                             label
# 0          5492        78        106154  -   Malicious   C&C-FileDownload
# 1           360         0             0               -   Malicious   C&C
# 2          7636       106        149732  -   Malicious   C&C-FileDownload
# 3          7406       106        149732  -   Malicious   C&C-FileDownload
# 4           360         0             0               -   Malicious   C&C
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-52-1/bro/conn.log.labeled
# --- 164.09190607070923 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled
#   proto   duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp          -          -          -         S0            0         1
# 1   udp          -          -          -         S0            0         1
# 2   udp          -          -          -         S0            0         1
# 3   udp  60.555587       3000          0         S0            0        10
# 4   udp  58.101145       3000          0         S0            0        10
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0           391         0             0  -   benign   -
# 1           411         0             0  -   benign   -
# 2           391         0             0  -   benign   -
# 3          3280         0             0  -   benign   -
# 4          3280         0             0  -   benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled
# --- 0.04109334945678711 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-39-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.017988         53        116         SF            0         1
# 1   udp  0.017239         52        115         SF            0         1
# 2   udp  0.018988         84        204         SF            0         2
# 3   udp  0.029489         74        448         SF            0         2
# 4   udp  0.002984         66        110         SF            0         2
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0            81         1           144  -   Benign   -
# 1            80         1           143  -   Benign   -
# 2           140         2           260  -   Benign   -
# 3           130         2           504  -   Benign   -
# 4           122         2           166  -   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-39-1/bro/conn.log.labeled
# --- 601.4335796833038 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-35-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp         -          -          -         S0            0         1
# 1   tcp         -          -          -         S0            0         1
# 2   udp  5.005148         78          0         S0            0         2
# 3   udp  5.005145         78          0         S0            0         2
# 4   tcp         -          -          -         S0            0         1
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                label
# 0            60         0             0  -   Malicious   C&C
# 1            60         0             0  -   Malicious   C&C
# 2           134         0             0       -   Benign   -
# 3           134         0             0       -   Benign   -
# 4            60         0             0  -   Malicious   C&C
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-35-1/bro/conn.log.labeled
# --- 77.33311009407043 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp  4.767024        150      67212         SF            0        54
# 1   tcp  3.107228          0          0         S0            0         3
# 2   udp  0.029483         58        146         SF            0         2
# 3   udp  0.001249         58        146         SF            0         2
# 4   tcp  3.714356        150      63183         SF            0        55
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                             label
# 0          2938        50         69224  -   Malicious   C&C-FileDownload
# 1           180         0             0                    -   Benign   -
# 2           114         2           202                    -   Benign   -
# 3           114         2           202                    -   Benign   -
# 4          3574        51         65235  -   Malicious   C&C-FileDownload
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled
# --- 0.07711911201477051 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled
#   proto    duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp    0.007496         96         96         SF            0         2
# 1   tcp    1.848549        518         66       RSTR            0        10
# 2   tcp  206.663644       2768      11216         SF            0       400
# 3   tcp    1.902519        518         66       RSTR            0        10
# 4   tcp    1.873781        518         66       RSTR            0        10
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                          label
# 0           152         2           152                 -   Benign   -
# 1          1572         8           540  -   Malicious   C&C-HeartBeat
# 2         26336       268         36368                 -   Benign   -
# 3          1572         8           540  -   Malicious   C&C-HeartBeat
# 4          1572         8           540  -   Malicious   C&C-HeartBeat
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled
# --- 27.473397493362427 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.004564          0       3900        SHR            0         0
# 1   udp  3.948539        876          0         S0            0         6
# 2   udp  3.768179        876          0         S0            0         6
# 3   udp  0.000114        451          0         S0            0        11
# 4   udp  3.756296        876          0         S0            0         6
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0             0        13          4264  -   benign   -
# 1          1164         0             0  -   benign   -
# 2          1164         0             0  -   benign   -
# 3           979         0             0  -   benign   -
# 4          1164         0             0  -   benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled
# --- 0.03126716613769531 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp  0.000002          0          0         S0            0         2
# 1   tcp  0.000005          0          0         S0            0         2
# 2   tcp  0.000003          0          0         S0            0         2
# 3   tcp  0.000002          0          0         S0            0         2
# 4   tcp  0.000002          0          0         S0            0         2
#
#   orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0            80         0             0
# 1            80         0             0
# 2            80         0             0
# 3            80         0             0
# 4            80         0             0
#
#                                        label
# 0  -   Malicious   PartOfAHorizontalPortScan
# 1                      -   Malicious   Okiru
# 2  -   Malicious   PartOfAHorizontalPortScan
# 3  -   Malicious   PartOfAHorizontalPortScan
# 4  -   Malicious   PartOfAHorizontalPortScan
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled
# --- 429.020423412323 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.000997         78        142         SF            0         2
# 1   udp  0.054470         78        254         SF            0         2
# 2   udp  0.053221         78        197         SF            0         2
# 3   udp  0.031732         78        197         SF            0         2
# 4   udp  0.000996         78        142         SF            0         2
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                 label
# 0           134         2           198  (empty)   Benign   -
# 1           134         2           310  (empty)   Benign   -
# 2           134         2           253  (empty)   Benign   -
# 3           134         2           253  (empty)   Benign   -
# 4           134         2           198  (empty)   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled
# --- 88.09531307220459 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled
#   proto    duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  160.367579       7536          0         S0            0        24
# 1   udp    0.016986         48         48         SF            0         1
# 2   tcp    0.003497          0          0         SF            0         5
# 3   udp    0.036724         34        311         SF            0         1
# 4   udp  384.518261      15072          0         S0            0        48
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0          8208         0             0  -   benign   -
# 1            76         1            76  -   benign   -
# 2           212         3           144  -   benign   -
# 3            62         1           339  -   benign   -
# 4         16416         0             0  -   benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled
# --- 0.03347635269165039 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp  3.081233          0          0         S0            0         3
# 1   tcp         -          -          -         S0            0         1
# 2   tcp         -          -          -         S0            0         1
# 3   tcp  1.847943        149     171878         SF         4344       102
# 4   tcp  1.500886        152     129941         SF        20272        83
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                             label
# 0           180         0             0               -   Malicious   C&C
# 1            60         0             0               -   Malicious   C&C
# 2            60         0             0               -   Malicious   C&C
# 3          6485       121        178178  -   Malicious   C&C-FileDownload
# 4          4696        94        136285  -   Malicious   C&C-FileDownload
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled
# --- 0.0294492244720459 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp         -          -          -         S0            0         1
# 1   tcp         -          -          -         S0            0         1
# 2   tcp  2.998796          0          0         S0            0         3
# 3   tcp         -          -          -         S0            0         1
# 4   tcp         -          -          -         S0            0         1
#
#   orig_ip_bytes resp_pkts resp_ip_bytes  \
# 0            60         0             0
# 1            60         0             0
# 2           180         0             0
# 3            60         0             0
# 4            60         0             0
#
#                                              label
# 0  (empty)   Malicious   PartOfAHorizontalPortScan
# 1  (empty)   Malicious   PartOfAHorizontalPortScan
# 2  (empty)   Malicious   PartOfAHorizontalPortScan
# 3  (empty)   Malicious   PartOfAHorizontalPortScan
# 4  (empty)   Malicious   PartOfAHorizontalPortScan
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled
# --- 10.750332355499268 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-49-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp  1.871487        151     198966         SF            0       282
# 1   tcp  2.376374        148     140547         SF            0       174
# 2   tcp  3.092539          0          0         S0            0         6
# 3   tcp  1.359780        148     137299         SF            0       178
# 4   tcp  1.952813        151     209560         SF            0       220
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                         label
# 0         15702       282        412612  -   Malicious   FileDownload
# 1          9600       201        291562  -   Malicious   FileDownload
# 2           360         0             0                -   Benign   -
# 3          9840       196        284806  -   Malicious   FileDownload
# 4         11878       296        434528  -   Malicious   FileDownload
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-49-1/bro/conn.log.labeled
# --- 48.36869764328003 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.007243         90         90         SF            0         2
# 1   udp  0.002250         90         90         SF            0         2
# 2   udp  5.005154         78          0         S0            0         2
# 3   udp  0.002246         90         90         SF            0         2
# 4   udp  5.005157         78          0         S0            0         2
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0           146         2           146  -   Benign   -
# 1           146         2           146  -   Benign   -
# 2           134         0             0  -   Benign   -
# 3           146         2           146  -   Benign   -
# 4           134         0             0  -   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled
# --- 0.06113719940185547 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.001741         48         48         SF            0         1
# 1   udp  0.004495         48         48         SF            0         1
# 2   udp  0.006988         48         48         SF            0         1
# 3   udp  0.001487         48         48         SF            0         1
# 4   udp  0.004739         48         48         SF            0         1
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                 label
# 0            76         1            76  (empty)   Benign   -
# 1            76         1            76  (empty)   Benign   -
# 2            76         1            76  (empty)   Benign   -
# 3            76         1            76  (empty)   Benign   -
# 4            76         1            76  (empty)   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
# --- 0.13716769218444824 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   tcp         -          -          -         S0            0         1
# 1   tcp         -          -          -         S0            0         1
# 2   tcp  1.477656        149     128252         SF         2896        94
# 3   tcp  3.147116          0          0         S0            0         3
# 4   tcp  1.305004        151     128348         SF         5792        96
#
#   orig_ip_bytes resp_pkts resp_ip_bytes           label
# 0            60         0             0  -   Benign   -
# 1            60         0             0  -   Benign   -
# 2          5525        96        139044  -   Benign   -
# 3           180         0             0  -   Benign   -
# 4          5699        92        133140  -   Benign   -
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled
# --- 0.24830079078674316 seconds ---
# Processing file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-43-1/bro/conn.log.labeled
#   proto  duration orig_bytes resp_bytes conn_state missed_bytes orig_pkts  \
# 0   udp  0.039224         39        103         SF            0         1
# 1   udp  0.000500         39         39         SF            0         1
# 2   tcp         -          -          -         S0            0         1
# 3   tcp         -          -          -         S0            0         1
# 4   tcp  0.761313        157      54305         SF         4344        41
#
#   orig_ip_bytes resp_pkts resp_ip_bytes                             label
# 0            67         1           131                    -   Benign   -
# 1            67         1            67                    -   Benign   -
# 2            60         0             0               -   Malicious   C&C
# 3            60         0             0               -   Malicious   C&C
# 4          2381        40         56393  -   Malicious   C&C-FileDownload
# Processed file : /home/mohit/data/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-43-1/bro/conn.log.labeled
# --- 521.5559151172638 seconds ---
